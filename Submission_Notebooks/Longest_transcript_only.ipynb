# %% [markdown]
# ## Longest Transcript Only (for orthofinder)

# %% [markdown]
# For orthofinder we are already putting in only the primary assembly, so it would be good to get the longest one from that.

# %%
# %matplotlib inline

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import Bio
from Bio.Seq import Seq
from Bio import SeqIO
from Bio.SeqUtils import IsoelectricPoint as IP

# %%
outpath = "/home/jemimah/databases/orthofinder_input/"
infn_fasta = outpath + "W_ceracea.fa"
brakerinfn = "/home/jemimah/analysis/v3/braker2/20200709_real/braker.gtf.reformatted"

# %% [markdown]
# First **identify if all transcripts have a .tX format**

# %%
braker_df = pd.read_csv(brakerinfn, sep = '\t')
geneless = braker_df[(braker_df["feature"] != "gene") & (braker_df["feature"] != "transcript")]
geneless.drop_duplicates(subset ="transcript_id", keep = "first", inplace = True)
geneless.sort_values("transcript_id", inplace = True)

pairs = geneless.copy()
del pairs["source"]
del pairs["start"]
del pairs["feature"]
del pairs["end"]
del pairs["score"]
del pairs["strand"]
del pairs["frame"]
del pairs["gene_id"]
pri_pairs = pairs[~pairs["seqname"].str.contains("hap_")]
pri_pairs.reset_index(level=0, inplace=True)
pri_pairs
# Out:
# <ipython-input-25-78dfe0a1c7db>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   geneless.drop_duplicates(subset ="transcript_id", keep = "first", inplace = True)
# <ipython-input-25-78dfe0a1c7db>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   geneless.sort_values("transcript_id", inplace = True)
#          index      seqname           transcript_id
# 0       709884  tig00007534  file_1_file_1_g1000.t1
# 1       199299  tig00007534  file_1_file_1_g1001.t1
# 2       788865  tig00007534  file_1_file_1_g1002.t1
# 3      1005830  tig00007534  file_1_file_1_g1003.t1
# 4       496937  tig00007534  file_1_file_1_g1004.t1
# ...        ...          ...                     ...
# 51937   723805  tig00013813          file_2_75741_t
# 51938    64026  tig00013813           file_2_7695_t
# 51939  1065120  tig00005423          file_2_77904_t
# 51940   985933  tig00001276           file_2_8500_t
# 51941   868237  tig00001276           file_2_8501_t
#
# [51942 rows x 3 columns]

# %% [markdown]
# We cannot use the start/end lengths in the braker table to select longest cds, as coding sequences have been combined in the braker2.aa result. So the first step is to figure out how many transcripts appear more than once in the primary assembly.

# %%
len(pri_pairs.transcript_id)
# Out:
# 51942

# %%
len(pri_pairs.transcript_id.str.rstrip('t1234567890').unique())
# Out:
# 50225

# %%
51942 - 50225
# Out:
# 1717

# %% [markdown]
# So there are 1717 things from the primary assembly that can be removed. The below list of transcript ids is what we want to check.

# %%
list(pri_pairs.transcript_id.str.rstrip('t1234567890').unique())
# Out:
# ['file_1_file_1_g1000.',
#  'file_1_file_1_g1001.',
#  'file_1_file_1_g1002.',
#  'file_1_file_1_g1003.',
#  'file_1_file_1_g1004.',
#  'file_1_file_1_g10044.',
#  'file_1_file_1_g10045.',
#  'file_1_file_1_g10046.',
#  'file_1_file_1_g10047.',
#  'file_1_file_1_g10048.',
#  'file_1_file_1_g10049.',
#  'file_1_file_1_g1005.',
#  'file_1_file_1_g10050.',
#  'file_1_file_1_g10051.',
#  'file_1_file_1_g10052.',
#  'file_1_file_1_g10053.',
#  'file_1_file_1_g10054.',
#  'file_1_file_1_g10055.',
#  'file_1_file_1_g10056.',
#  'file_1_file_1_g10057.',
#  'file_1_file_1_g10058.',
#  'file_1_file_1_g10059.',
#  'file_1_file_1_g1006.',
#  'file_1_file_1_g10060.',
#  'file_1_file_1_g10061.',
#  'file_1_file_1_g10062.',
#  'file_1_file_1_g10067.',
#  'file_1_file_1_g10068.',
#  'file_1_file_1_g10069.',
#  'file_1_file_1_g1007.',
#  'file_1_file_1_g1008.',
#  'file_1_file_1_g1009.',
#  'file_1_file_1_g1010.',
#  'file_1_file_1_g1011.',
#  'file_1_file_1_g1012.',
#  'file_1_file_1_g10126.',
#  'file_1_file_1_g10127.',
#  'file_1_file_1_g10128.',
#  'file_1_file_1_g10129.',
#  'file_1_file_1_g1013.',
#  'file_1_file_1_g10130.',
#  'file_1_file_1_g10131.',
#  'file_1_file_1_g10132.',
#  'file_1_file_1_g10133.',
#  'file_1_file_1_g10134.',
#  'file_1_file_1_g10135.',
#  'file_1_file_1_g10136.',
#  'file_1_file_1_g10137.',
#  'file_1_file_1_g10138.',
#  'file_1_file_1_g10139.',
#  'file_1_file_1_g1014.',
#  'file_1_file_1_g10140.',
#  'file_1_file_1_g10141.',
#  'file_1_file_1_g10142.',
#  'file_1_file_1_g10143.',
#  'file_1_file_1_g1015.',
#  'file_1_file_1_g1016.',
#  'file_1_file_1_g1017.',
#  'file_1_file_1_g10179.',
#  'file_1_file_1_g1018.',
#  'file_1_file_1_g10180.',
#  'file_1_file_1_g10181.',
#  'file_1_file_1_g10182.',
#  'file_1_file_1_g10183.',
#  'file_1_file_1_g10184.',
#  'file_1_file_1_g10185.',
#  'file_1_file_1_g10186.',
#  'file_1_file_1_g10187.',
#  'file_1_file_1_g10188.',
#  'file_1_file_1_g10189.',
#  'file_1_file_1_g1019.',
#  'file_1_file_1_g10190.',
#  'file_1_file_1_g10191.',
#  'file_1_file_1_g10192.',
#  'file_1_file_1_g10193.',
#  'file_1_file_1_g10194.',
#  'file_1_file_1_g10195.',
#  'file_1_file_1_g10196.',
#  'file_1_file_1_g10197.',
#  'file_1_file_1_g10198.',
#  'file_1_file_1_g10199.',
#  'file_1_file_1_g1020.',
#  'file_1_file_1_g10200.',
#  'file_1_file_1_g10201.',
#  'file_1_file_1_g10202.',
#  'file_1_file_1_g10203.',
#  'file_1_file_1_g10204.',
#  'file_1_file_1_g10205.',
#  'file_1_file_1_g10206.',
#  'file_1_file_1_g10207.',
#  'file_1_file_1_g10208.',
#  'file_1_file_1_g10209.',
#  'file_1_file_1_g1021.',
#  'file_1_file_1_g10210.',
#  'file_1_file_1_g10211.',
#  'file_1_file_1_g10212.',
#  'file_1_file_1_g10213.',
#  'file_1_file_1_g10214.',
#  'file_1_file_1_g10215.',
#  'file_1_file_1_g10216.',
#  'file_1_file_1_g10217.',
#  'file_1_file_1_g10218.',
#  'file_1_file_1_g10219.',
#  'file_1_file_1_g1022.',
#  'file_1_file_1_g10220.',
#  'file_1_file_1_g10221.',
#  'file_1_file_1_g10222.',
#  'file_1_file_1_g10223.',
#  'file_1_file_1_g10224.',
#  'file_1_file_1_g10225.',
#  'file_1_file_1_g10226.',
#  'file_1_file_1_g10227.',
#  'file_1_file_1_g10228.',
#  'file_1_file_1_g1023.',
#  'file_1_file_1_g1024.',
#  'file_1_file_1_g1025.',
#  'file_1_file_1_g10259.',
#  'file_1_file_1_g1026.',
#  'file_1_file_1_g10260.',
#  'file_1_file_1_g10261.',
#  'file_1_file_1_g10262.',
#  'file_1_file_1_g10263.',
#  'file_1_file_1_g10264.',
#  'file_1_file_1_g10265.',
#  'file_1_file_1_g10266.',
#  'file_1_file_1_g10267.',
#  'file_1_file_1_g10268.',
#  'file_1_file_1_g10269.',
#  'file_1_file_1_g1027.',
#  'file_1_file_1_g10270.',
#  'file_1_file_1_g10271.',
#  'file_1_file_1_g10272.',
#  'file_1_file_1_g10273.',
#  'file_1_file_1_g10274.',
#  'file_1_file_1_g10275.',
#  'file_1_file_1_g10276.',
#  'file_1_file_1_g10277.',
#  'file_1_file_1_g10278.',
#  'file_1_file_1_g10279.',
#  'file_1_file_1_g1028.',
#  'file_1_file_1_g10280.',
#  'file_1_file_1_g10281.',
#  'file_1_file_1_g10282.',
#  'file_1_file_1_g10283.',
#  'file_1_file_1_g10284.',
#  'file_1_file_1_g10285.',
#  'file_1_file_1_g10286.',
#  'file_1_file_1_g10287.',
#  'file_1_file_1_g10288.',
#  'file_1_file_1_g10289.',
#  'file_1_file_1_g1029.',
#  'file_1_file_1_g10290.',
#  'file_1_file_1_g10291.',
#  'file_1_file_1_g10292.',
#  'file_1_file_1_g10293.',
#  'file_1_file_1_g10294.',
#  'file_1_file_1_g10295.',
#  'file_1_file_1_g10296.',
#  'file_1_file_1_g10297.',
#  'file_1_file_1_g10298.',
#  'file_1_file_1_g10299.',
#  'file_1_file_1_g1030.',
#  'file_1_file_1_g10300.',
#  'file_1_file_1_g10301.',
#  'file_1_file_1_g10302.',
#  'file_1_file_1_g10303.',
#  'file_1_file_1_g10304.',
#  'file_1_file_1_g10305.',
#  'file_1_file_1_g10306.',
#  'file_1_file_1_g10307.',
#  'file_1_file_1_g10308.',
#  'file_1_file_1_g10309.',
#  'file_1_file_1_g1031.',
#  'file_1_file_1_g10310.',
#  'file_1_file_1_g10311.',
#  'file_1_file_1_g10312.',
#  'file_1_file_1_g10313.',
#  'file_1_file_1_g10314.',
#  'file_1_file_1_g10315.',
#  'file_1_file_1_g10316.',
#  'file_1_file_1_g10317.',
#  'file_1_file_1_g10318.',
#  'file_1_file_1_g10319.',
#  'file_1_file_1_g1032.',
#  'file_1_file_1_g10320.',
#  'file_1_file_1_g10321.',
#  'file_1_file_1_g10322.',
#  'file_1_file_1_g10323.',
#  'file_1_file_1_g10324.',
#  'file_1_file_1_g10325.',
#  'file_1_file_1_g10326.',
#  'file_1_file_1_g10327.',
#  'file_1_file_1_g10328.',
#  'file_1_file_1_g10329.',
#  'file_1_file_1_g1033.',
#  'file_1_file_1_g10330.',
#  'file_1_file_1_g10331.',
#  'file_1_file_1_g10332.',
#  'file_1_file_1_g10333.',
#  'file_1_file_1_g10334.',
#  'file_1_file_1_g10335.',
#  'file_1_file_1_g10336.',
#  'file_1_file_1_g10337.',
#  'file_1_file_1_g10338.',
#  'file_1_file_1_g10339.',
#  'file_1_file_1_g1034.',
#  'file_1_file_1_g10340.',
#  'file_1_file_1_g10341.',
#  'file_1_file_1_g10342.',
#  'file_1_file_1_g10343.',
#  'file_1_file_1_g10344.',
#  'file_1_file_1_g10345.',
#  'file_1_file_1_g10346.',
#  'file_1_file_1_g10347.',
#  'file_1_file_1_g10348.',
#  'file_1_file_1_g10349.',
#  'file_1_file_1_g1035.',
#  'file_1_file_1_g10350.',
#  'file_1_file_1_g10351.',
#  'file_1_file_1_g10352.',
#  'file_1_file_1_g10353.',
#  'file_1_file_1_g10354.',
#  'file_1_file_1_g10355.',
#  'file_1_file_1_g10356.',
#  'file_1_file_1_g10357.',
#  'file_1_file_1_g10358.',
#  'file_1_file_1_g10359.',
#  'file_1_file_1_g1036.',
#  'file_1_file_1_g10360.',
#  'file_1_file_1_g10361.',
#  'file_1_file_1_g10362.',
#  'file_1_file_1_g10363.',
#  'file_1_file_1_g10364.',
#  'file_1_file_1_g10365.',
#  'file_1_file_1_g10366.',
#  'file_1_file_1_g10367.',
#  'file_1_file_1_g10368.',
#  'file_1_file_1_g10369.',
#  'file_1_file_1_g1037.',
#  'file_1_file_1_g10370.',
#  'file_1_file_1_g10371.',
#  'file_1_file_1_g10372.',
#  'file_1_file_1_g10373.',
#  'file_1_file_1_g10374.',
#  'file_1_file_1_g10375.',
#  'file_1_file_1_g10376.',
#  'file_1_file_1_g10377.',
#  'file_1_file_1_g10378.',
#  'file_1_file_1_g10379.',
#  'file_1_file_1_g1038.',
#  'file_1_file_1_g10380.',
#  'file_1_file_1_g10381.',
#  'file_1_file_1_g10382.',
#  'file_1_file_1_g10383.',
#  'file_1_file_1_g10384.',
#  'file_1_file_1_g10385.',
#  'file_1_file_1_g10386.',
#  'file_1_file_1_g10387.',
#  'file_1_file_1_g10388.',
#  'file_1_file_1_g10389.',
#  'file_1_file_1_g1039.',
#  'file_1_file_1_g10390.',
#  'file_1_file_1_g10391.',
#  'file_1_file_1_g10392.',
#  'file_1_file_1_g10393.',
#  'file_1_file_1_g10394.',
#  'file_1_file_1_g10395.',
#  'file_1_file_1_g1040.',
#  'file_1_file_1_g1041.',
#  'file_1_file_1_g1042.',
#  'file_1_file_1_g1043.',
#  'file_1_file_1_g1044.',
#  'file_1_file_1_g1045.',
#  'file_1_file_1_g1046.',
#  'file_1_file_1_g1047.',
#  'file_1_file_1_g1048.',
#  'file_1_file_1_g1049.',
#  'file_1_file_1_g1050.',
#  'file_1_file_1_g1051.',
#  'file_1_file_1_g1052.',
#  'file_1_file_1_g1053.',
#  'file_1_file_1_g1054.',
#  'file_1_file_1_g1055.',
#  'file_1_file_1_g10556.',
#  'file_1_file_1_g10557.',
#  'file_1_file_1_g10558.',
#  'file_1_file_1_g10559.',
#  'file_1_file_1_g1056.',
#  'file_1_file_1_g10560.',
#  'file_1_file_1_g10561.',
#  'file_1_file_1_g10562.',
#  'file_1_file_1_g10563.',
#  'file_1_file_1_g10564.',
#  'file_1_file_1_g10565.',
#  'file_1_file_1_g10569.',
#  'file_1_file_1_g1057.',
#  'file_1_file_1_g10570.',
#  'file_1_file_1_g10571.',
#  'file_1_file_1_g10572.',
#  'file_1_file_1_g10573.',
#  'file_1_file_1_g10574.',
#  'file_1_file_1_g10575.',
#  'file_1_file_1_g10576.',
#  'file_1_file_1_g10577.',
#  'file_1_file_1_g10578.',
#  'file_1_file_1_g10579.',
#  'file_1_file_1_g1058.',
#  'file_1_file_1_g10580.',
#  'file_1_file_1_g10581.',
#  'file_1_file_1_g10582.',
#  'file_1_file_1_g10583.',
#  'file_1_file_1_g10584.',
#  'file_1_file_1_g10585.',
#  'file_1_file_1_g10586.',
#  'file_1_file_1_g10587.',
#  'file_1_file_1_g10588.',
#  'file_1_file_1_g10589.',
#  'file_1_file_1_g1059.',
#  'file_1_file_1_g10590.',
#  'file_1_file_1_g10591.',
#  'file_1_file_1_g10592.',
#  'file_1_file_1_g10593.',
#  'file_1_file_1_g10594.',
#  'file_1_file_1_g10595.',
#  'file_1_file_1_g10596.',
#  'file_1_file_1_g10597.',
#  'file_1_file_1_g10598.',
#  'file_1_file_1_g10599.',
#  'file_1_file_1_g1060.',
#  'file_1_file_1_g10600.',
#  'file_1_file_1_g10601.',
#  'file_1_file_1_g10602.',
#  'file_1_file_1_g10603.',
#  'file_1_file_1_g1061.',
#  'file_1_file_1_g1062.',
#  'file_1_file_1_g10624.',
#  'file_1_file_1_g10625.',
#  'file_1_file_1_g10626.',
#  'file_1_file_1_g10627.',
#  'file_1_file_1_g10628.',
#  'file_1_file_1_g10629.',
#  'file_1_file_1_g1063.',
#  'file_1_file_1_g10630.',
#  'file_1_file_1_g10631.',
#  'file_1_file_1_g10632.',
#  'file_1_file_1_g10633.',
#  'file_1_file_1_g10634.',
#  'file_1_file_1_g10635.',
#  'file_1_file_1_g10636.',
#  'file_1_file_1_g10637.',
#  'file_1_file_1_g10638.',
#  'file_1_file_1_g10639.',
#  'file_1_file_1_g1064.',
#  'file_1_file_1_g10640.',
#  'file_1_file_1_g10641.',
#  'file_1_file_1_g10642.',
#  'file_1_file_1_g10643.',
#  'file_1_file_1_g10644.',
#  'file_1_file_1_g10645.',
#  'file_1_file_1_g10646.',
#  'file_1_file_1_g10647.',
#  'file_1_file_1_g10648.',
#  'file_1_file_1_g10649.',
#  'file_1_file_1_g1065.',
#  'file_1_file_1_g10650.',
#  'file_1_file_1_g10651.',
#  'file_1_file_1_g10652.',
#  'file_1_file_1_g1066.',
#  'file_1_file_1_g10660.',
#  'file_1_file_1_g10661.',
#  'file_1_file_1_g10662.',
#  'file_1_file_1_g10663.',
#  'file_1_file_1_g10664.',
#  'file_1_file_1_g10665.',
#  'file_1_file_1_g10666.',
#  'file_1_file_1_g10667.',
#  'file_1_file_1_g1067.',
#  'file_1_file_1_g1068.',
#  'file_1_file_1_g1069.',
#  'file_1_file_1_g1070.',
#  'file_1_file_1_g1071.',
#  'file_1_file_1_g10715.',
#  'file_1_file_1_g10716.',
#  'file_1_file_1_g10717.',
#  'file_1_file_1_g10718.',
#  'file_1_file_1_g10719.',
#  'file_1_file_1_g1072.',
#  'file_1_file_1_g10720.',
#  'file_1_file_1_g10721.',
#  'file_1_file_1_g10722.',
#  'file_1_file_1_g10723.',
#  'file_1_file_1_g10724.',
#  'file_1_file_1_g10725.',
#  'file_1_file_1_g10726.',
#  'file_1_file_1_g10727.',
#  'file_1_file_1_g10728.',
#  'file_1_file_1_g10729.',
#  'file_1_file_1_g1073.',
#  'file_1_file_1_g10730.',
#  'file_1_file_1_g10731.',
#  'file_1_file_1_g10732.',
#  'file_1_file_1_g10733.',
#  'file_1_file_1_g10734.',
#  'file_1_file_1_g10735.',
#  'file_1_file_1_g10736.',
#  'file_1_file_1_g10737.',
#  'file_1_file_1_g10738.',
#  'file_1_file_1_g10739.',
#  'file_1_file_1_g1074.',
#  'file_1_file_1_g10740.',
#  'file_1_file_1_g10741.',
#  'file_1_file_1_g10742.',
#  'file_1_file_1_g10743.',
#  'file_1_file_1_g10744.',
#  'file_1_file_1_g10745.',
#  'file_1_file_1_g10746.',
#  'file_1_file_1_g10747.',
#  'file_1_file_1_g10748.',
#  'file_1_file_1_g10749.',
#  'file_1_file_1_g1075.',
#  'file_1_file_1_g10750.',
#  'file_1_file_1_g10751.',
#  'file_1_file_1_g10752.',
#  'file_1_file_1_g10753.',
#  'file_1_file_1_g10754.',
#  'file_1_file_1_g10755.',
#  'file_1_file_1_g10756.',
#  'file_1_file_1_g10757.',
#  'file_1_file_1_g10758.',
#  'file_1_file_1_g10759.',
#  'file_1_file_1_g1076.',
#  'file_1_file_1_g10760.',
#  'file_1_file_1_g10761.',
#  'file_1_file_1_g10762.',
#  'file_1_file_1_g10763.',
#  'file_1_file_1_g10764.',
#  'file_1_file_1_g10765.',
#  'file_1_file_1_g10766.',
#  'file_1_file_1_g10767.',
#  'file_1_file_1_g10768.',
#  'file_1_file_1_g10769.',
#  'file_1_file_1_g1077.',
#  'file_1_file_1_g10770.',
#  'file_1_file_1_g10771.',
#  'file_1_file_1_g10772.',
#  'file_1_file_1_g10773.',
#  'file_1_file_1_g10774.',
#  'file_1_file_1_g10775.',
#  'file_1_file_1_g10776.',
#  'file_1_file_1_g10777.',
#  'file_1_file_1_g10778.',
#  'file_1_file_1_g10779.',
#  'file_1_file_1_g1078.',
#  'file_1_file_1_g1079.',
#  'file_1_file_1_g1080.',
#  'file_1_file_1_g1081.',
#  'file_1_file_1_g1082.',
#  'file_1_file_1_g1083.',
#  'file_1_file_1_g1084.',
#  'file_1_file_1_g10924.',
#  'file_1_file_1_g10925.',
#  'file_1_file_1_g10934.',
#  'file_1_file_1_g10935.',
#  'file_1_file_1_g10936.',
#  'file_1_file_1_g10937.',
#  'file_1_file_1_g10938.',
#  'file_1_file_1_g10939.',
#  'file_1_file_1_g10940.',
#  'file_1_file_1_g10941.',
#  'file_1_file_1_g10942.',
#  'file_1_file_1_g10943.',
#  'file_1_file_1_g10944.',
#  'file_1_file_1_g10945.',
#  'file_1_file_1_g10946.',
#  'file_1_file_1_g10947.',
#  'file_1_file_1_g10948.',
#  'file_1_file_1_g10955.',
#  'file_1_file_1_g10956.',
#  'file_1_file_1_g10957.',
#  'file_1_file_1_g10958.',
#  'file_1_file_1_g10959.',
#  'file_1_file_1_g10960.',
#  'file_1_file_1_g10961.',
#  'file_1_file_1_g10962.',
#  'file_1_file_1_g10963.',
#  'file_1_file_1_g10964.',
#  'file_1_file_1_g10965.',
#  'file_1_file_1_g10966.',
#  'file_1_file_1_g10967.',
#  'file_1_file_1_g10968.',
#  'file_1_file_1_g10969.',
#  'file_1_file_1_g10970.',
#  'file_1_file_1_g10971.',
#  'file_1_file_1_g10972.',
#  'file_1_file_1_g10973.',
#  'file_1_file_1_g10974.',
#  'file_1_file_1_g10975.',
#  'file_1_file_1_g10976.',
#  'file_1_file_1_g10977.',
#  'file_1_file_1_g10978.',
#  'file_1_file_1_g10979.',
#  'file_1_file_1_g10980.',
#  'file_1_file_1_g10981.',
#  'file_1_file_1_g10982.',
#  'file_1_file_1_g10983.',
#  'file_1_file_1_g10984.',
#  'file_1_file_1_g10985.',
#  'file_1_file_1_g10986.',
#  'file_1_file_1_g10987.',
#  'file_1_file_1_g10988.',
#  'file_1_file_1_g10989.',
#  'file_1_file_1_g10990.',
#  'file_1_file_1_g10991.',
#  'file_1_file_1_g10992.',
#  'file_1_file_1_g10993.',
#  'file_1_file_1_g10994.',
#  'file_1_file_1_g10995.',
#  'file_1_file_1_g10996.',
#  'file_1_file_1_g10997.',
#  'file_1_file_1_g10998.',
#  'file_1_file_1_g10999.',
#  'file_1_file_1_g11000.',
#  'file_1_file_1_g11001.',
#  'file_1_file_1_g11002.',
#  'file_1_file_1_g11003.',
#  'file_1_file_1_g11004.',
#  'file_1_file_1_g11005.',
#  'file_1_file_1_g11006.',
#  'file_1_file_1_g11007.',
#  'file_1_file_1_g11008.',
#  'file_1_file_1_g11009.',
#  'file_1_file_1_g11010.',
#  'file_1_file_1_g11011.',
#  'file_1_file_1_g11012.',
#  'file_1_file_1_g11013.',
#  'file_1_file_1_g11014.',
#  'file_1_file_1_g11015.',
#  'file_1_file_1_g11016.',
#  'file_1_file_1_g11017.',
#  'file_1_file_1_g11018.',
#  'file_1_file_1_g11019.',
#  'file_1_file_1_g11020.',
#  'file_1_file_1_g11021.',
#  'file_1_file_1_g11022.',
#  'file_1_file_1_g11023.',
#  'file_1_file_1_g11024.',
#  'file_1_file_1_g11025.',
#  'file_1_file_1_g11026.',
#  'file_1_file_1_g11027.',
#  'file_1_file_1_g11028.',
#  'file_1_file_1_g11029.',
#  'file_1_file_1_g11030.',
#  'file_1_file_1_g11031.',
#  'file_1_file_1_g11032.',
#  'file_1_file_1_g11033.',
#  'file_1_file_1_g11034.',
#  'file_1_file_1_g11035.',
#  'file_1_file_1_g11036.',
#  'file_1_file_1_g11037.',
#  'file_1_file_1_g11038.',
#  'file_1_file_1_g11039.',
#  'file_1_file_1_g11040.',
#  'file_1_file_1_g11041.',
#  'file_1_file_1_g11042.',
#  'file_1_file_1_g11043.',
#  'file_1_file_1_g11044.',
#  'file_1_file_1_g11045.',
#  'file_1_file_1_g11046.',
#  'file_1_file_1_g11047.',
#  'file_1_file_1_g11048.',
#  'file_1_file_1_g11049.',
#  'file_1_file_1_g11050.',
#  'file_1_file_1_g11051.',
#  'file_1_file_1_g11052.',
#  'file_1_file_1_g11053.',
#  'file_1_file_1_g11054.',
#  'file_1_file_1_g11055.',
#  'file_1_file_1_g11057.',
#  'file_1_file_1_g11058.',
#  'file_1_file_1_g11059.',
#  'file_1_file_1_g11060.',
#  'file_1_file_1_g11061.',
#  'file_1_file_1_g11062.',
#  'file_1_file_1_g11063.',
#  'file_1_file_1_g11064.',
#  'file_1_file_1_g11065.',
#  'file_1_file_1_g11066.',
#  'file_1_file_1_g11067.',
#  'file_1_file_1_g11068.',
#  'file_1_file_1_g11069.',
#  'file_1_file_1_g11070.',
#  'file_1_file_1_g11071.',
#  'file_1_file_1_g11072.',
#  'file_1_file_1_g11073.',
#  'file_1_file_1_g11074.',
#  'file_1_file_1_g11075.',
#  'file_1_file_1_g11076.',
#  'file_1_file_1_g11077.',
#  'file_1_file_1_g11078.',
#  'file_1_file_1_g11079.',
#  'file_1_file_1_g11080.',
#  'file_1_file_1_g11081.',
#  'file_1_file_1_g11082.',
#  'file_1_file_1_g11083.',
#  'file_1_file_1_g11084.',
#  'file_1_file_1_g11085.',
#  'file_1_file_1_g11086.',
#  'file_1_file_1_g11087.',
#  'file_1_file_1_g11088.',
#  'file_1_file_1_g11089.',
#  'file_1_file_1_g11090.',
#  'file_1_file_1_g11091.',
#  'file_1_file_1_g11092.',
#  'file_1_file_1_g11093.',
#  'file_1_file_1_g11094.',
#  'file_1_file_1_g11095.',
#  'file_1_file_1_g11096.',
#  'file_1_file_1_g11097.',
#  'file_1_file_1_g11098.',
#  'file_1_file_1_g11099.',
#  'file_1_file_1_g11100.',
#  'file_1_file_1_g11101.',
#  'file_1_file_1_g11102.',
#  'file_1_file_1_g11103.',
#  'file_1_file_1_g11104.',
#  'file_1_file_1_g11105.',
#  'file_1_file_1_g11106.',
#  'file_1_file_1_g11107.',
#  'file_1_file_1_g11108.',
#  'file_1_file_1_g11109.',
#  'file_1_file_1_g11110.',
#  'file_1_file_1_g11111.',
#  'file_1_file_1_g11112.',
#  'file_1_file_1_g11113.',
#  'file_1_file_1_g11114.',
#  'file_1_file_1_g11115.',
#  'file_1_file_1_g11116.',
#  'file_1_file_1_g11117.',
#  'file_1_file_1_g11118.',
#  'file_1_file_1_g11119.',
#  'file_1_file_1_g11120.',
#  'file_1_file_1_g11121.',
#  'file_1_file_1_g11122.',
#  'file_1_file_1_g11123.',
#  'file_1_file_1_g11124.',
#  'file_1_file_1_g11125.',
#  'file_1_file_1_g11126.',
#  'file_1_file_1_g11127.',
#  'file_1_file_1_g11128.',
#  'file_1_file_1_g11129.',
#  'file_1_file_1_g11130.',
#  'file_1_file_1_g11131.',
#  'file_1_file_1_g11132.',
#  'file_1_file_1_g11133.',
#  'file_1_file_1_g11134.',
#  'file_1_file_1_g11135.',
#  'file_1_file_1_g11136.',
#  'file_1_file_1_g11137.',
#  'file_1_file_1_g11138.',
#  'file_1_file_1_g11139.',
#  'file_1_file_1_g11140.',
#  'file_1_file_1_g11141.',
#  'file_1_file_1_g11142.',
#  'file_1_file_1_g11143.',
#  'file_1_file_1_g11144.',
#  'file_1_file_1_g11145.',
#  'file_1_file_1_g11146.',
#  'file_1_file_1_g11147.',
#  'file_1_file_1_g11148.',
#  'file_1_file_1_g11149.',
#  'file_1_file_1_g11150.',
#  'file_1_file_1_g11151.',
#  'file_1_file_1_g11152.',
#  'file_1_file_1_g11153.',
#  'file_1_file_1_g11154.',
#  'file_1_file_1_g11155.',
#  'file_1_file_1_g11156.',
#  'file_1_file_1_g11159.',
#  'file_1_file_1_g11160.',
#  'file_1_file_1_g11161.',
#  'file_1_file_1_g11162.',
#  'file_1_file_1_g11163.',
#  'file_1_file_1_g11164.',
#  'file_1_file_1_g11165.',
#  'file_1_file_1_g11166.',
#  'file_1_file_1_g11167.',
#  'file_1_file_1_g11168.',
#  'file_1_file_1_g11169.',
#  'file_1_file_1_g11170.',
#  'file_1_file_1_g11171.',
#  'file_1_file_1_g11172.',
#  'file_1_file_1_g11173.',
#  'file_1_file_1_g11174.',
#  'file_1_file_1_g11175.',
#  'file_1_file_1_g11176.',
#  'file_1_file_1_g11177.',
#  'file_1_file_1_g11178.',
#  'file_1_file_1_g11179.',
#  'file_1_file_1_g11180.',
#  'file_1_file_1_g11181.',
#  'file_1_file_1_g11182.',
#  'file_1_file_1_g11183.',
#  'file_1_file_1_g11184.',
#  'file_1_file_1_g11185.',
#  'file_1_file_1_g11186.',
#  'file_1_file_1_g11187.',
#  'file_1_file_1_g11188.',
#  'file_1_file_1_g11189.',
#  'file_1_file_1_g11190.',
#  'file_1_file_1_g11191.',
#  'file_1_file_1_g11192.',
#  'file_1_file_1_g11193.',
#  'file_1_file_1_g11194.',
#  'file_1_file_1_g11195.',
#  'file_1_file_1_g11196.',
#  'file_1_file_1_g11197.',
#  'file_1_file_1_g11198.',
#  'file_1_file_1_g11199.',
#  'file_1_file_1_g11200.',
#  'file_1_file_1_g11201.',
#  'file_1_file_1_g11202.',
#  'file_1_file_1_g11203.',
#  'file_1_file_1_g11204.',
#  'file_1_file_1_g11205.',
#  'file_1_file_1_g11206.',
#  'file_1_file_1_g11207.',
#  'file_1_file_1_g11208.',
#  'file_1_file_1_g11209.',
#  'file_1_file_1_g11210.',
#  'file_1_file_1_g11211.',
#  'file_1_file_1_g11212.',
#  'file_1_file_1_g11213.',
#  'file_1_file_1_g11214.',
#  'file_1_file_1_g11215.',
#  'file_1_file_1_g11216.',
#  'file_1_file_1_g11217.',
#  'file_1_file_1_g11218.',
#  'file_1_file_1_g11219.',
#  'file_1_file_1_g11220.',
#  'file_1_file_1_g11221.',
#  'file_1_file_1_g11222.',
#  'file_1_file_1_g11223.',
#  'file_1_file_1_g11224.',
#  'file_1_file_1_g11225.',
#  'file_1_file_1_g11226.',
#  'file_1_file_1_g11227.',
#  'file_1_file_1_g11228.',
#  'file_1_file_1_g11229.',
#  'file_1_file_1_g11230.',
#  'file_1_file_1_g11231.',
#  'file_1_file_1_g11232.',
#  'file_1_file_1_g11233.',
#  'file_1_file_1_g11234.',
#  'file_1_file_1_g11235.',
#  'file_1_file_1_g11236.',
#  'file_1_file_1_g11237.',
#  'file_1_file_1_g11238.',
#  'file_1_file_1_g11239.',
#  'file_1_file_1_g11240.',
#  'file_1_file_1_g11241.',
#  'file_1_file_1_g11242.',
#  'file_1_file_1_g11275.',
#  'file_1_file_1_g11276.',
#  'file_1_file_1_g11277.',
#  'file_1_file_1_g11278.',
#  'file_1_file_1_g11279.',
#  'file_1_file_1_g11280.',
#  'file_1_file_1_g11281.',
#  'file_1_file_1_g11282.',
#  'file_1_file_1_g11283.',
#  'file_1_file_1_g11284.',
#  'file_1_file_1_g11285.',
#  'file_1_file_1_g11286.',
#  'file_1_file_1_g11287.',
#  'file_1_file_1_g11288.',
#  'file_1_file_1_g11289.',
#  'file_1_file_1_g11290.',
#  'file_1_file_1_g11291.',
#  'file_1_file_1_g11292.',
#  'file_1_file_1_g11293.',
#  'file_1_file_1_g11294.',
#  'file_1_file_1_g11295.',
#  'file_1_file_1_g11296.',
#  'file_1_file_1_g11297.',
#  'file_1_file_1_g11298.',
#  'file_1_file_1_g11299.',
#  'file_1_file_1_g11300.',
#  'file_1_file_1_g11301.',
#  'file_1_file_1_g11302.',
#  'file_1_file_1_g11303.',
#  'file_1_file_1_g11304.',
#  'file_1_file_1_g11305.',
#  'file_1_file_1_g11306.',
#  'file_1_file_1_g11307.',
#  'file_1_file_1_g11308.',
#  'file_1_file_1_g11309.',
#  'file_1_file_1_g11310.',
#  'file_1_file_1_g11311.',
#  'file_1_file_1_g11312.',
#  'file_1_file_1_g11313.',
#  'file_1_file_1_g11408.',
#  'file_1_file_1_g11409.',
#  'file_1_file_1_g11410.',
#  'file_1_file_1_g11411.',
#  'file_1_file_1_g11412.',
#  'file_1_file_1_g11413.',
#  'file_1_file_1_g11414.',
#  'file_1_file_1_g11415.',
#  'file_1_file_1_g11416.',
#  'file_1_file_1_g11417.',
#  'file_1_file_1_g11418.',
#  'file_1_file_1_g11419.',
#  'file_1_file_1_g11420.',
#  'file_1_file_1_g11421.',
#  'file_1_file_1_g11422.',
#  'file_1_file_1_g11423.',
#  'file_1_file_1_g11424.',
#  'file_1_file_1_g11425.',
#  'file_1_file_1_g11426.',
#  'file_1_file_1_g11427.',
#  'file_1_file_1_g11428.',
#  'file_1_file_1_g11429.',
#  'file_1_file_1_g11430.',
#  'file_1_file_1_g11431.',
#  'file_1_file_1_g11432.',
#  'file_1_file_1_g11433.',
#  'file_1_file_1_g11434.',
#  'file_1_file_1_g11435.',
#  'file_1_file_1_g11436.',
#  'file_1_file_1_g11437.',
#  'file_1_file_1_g11438.',
#  'file_1_file_1_g11439.',
#  'file_1_file_1_g11440.',
#  'file_1_file_1_g11441.',
#  'file_1_file_1_g11442.',
#  'file_1_file_1_g11443.',
#  'file_1_file_1_g11444.',
#  'file_1_file_1_g11445.',
#  'file_1_file_1_g11446.',
#  'file_1_file_1_g11447.',
#  'file_1_file_1_g11448.',
#  'file_1_file_1_g11449.',
#  'file_1_file_1_g11450.',
#  'file_1_file_1_g11451.',
#  'file_1_file_1_g11452.',
#  'file_1_file_1_g11453.',
#  'file_1_file_1_g11454.',
#  'file_1_file_1_g11455.',
#  'file_1_file_1_g11456.',
#  'file_1_file_1_g11457.',
#  'file_1_file_1_g11458.',
#  'file_1_file_1_g11459.',
#  'file_1_file_1_g11460.',
#  'file_1_file_1_g11461.',
#  'file_1_file_1_g11462.',
#  'file_1_file_1_g11463.',
#  'file_1_file_1_g11464.',
#  'file_1_file_1_g11465.',
#  'file_1_file_1_g11466.',
#  'file_1_file_1_g11467.',
#  'file_1_file_1_g11468.',
#  'file_1_file_1_g11469.',
#  'file_1_file_1_g11470.',
#  'file_1_file_1_g11471.',
#  'file_1_file_1_g11472.',
#  'file_1_file_1_g11473.',
#  'file_1_file_1_g11474.',
#  'file_1_file_1_g11476.',
#  'file_1_file_1_g11477.',
#  'file_1_file_1_g11478.',
#  'file_1_file_1_g11487.',
#  'file_1_file_1_g11488.',
#  'file_1_file_1_g11489.',
#  'file_1_file_1_g11490.',
#  'file_1_file_1_g11518.',
#  'file_1_file_1_g11519.',
#  'file_1_file_1_g11520.',
#  'file_1_file_1_g11536.',
#  'file_1_file_1_g11537.',
#  'file_1_file_1_g11538.',
#  'file_1_file_1_g11539.',
#  'file_1_file_1_g11540.',
#  'file_1_file_1_g11541.',
#  'file_1_file_1_g11542.',
#  'file_1_file_1_g11543.',
#  'file_1_file_1_g11544.',
#  'file_1_file_1_g11545.',
#  'file_1_file_1_g11546.',
#  'file_1_file_1_g11547.',
#  'file_1_file_1_g11548.',
#  'file_1_file_1_g11549.',
#  'file_1_file_1_g11550.',
#  'file_1_file_1_g11551.',
#  'file_1_file_1_g11552.',
#  'file_1_file_1_g11553.',
#  'file_1_file_1_g11554.',
#  'file_1_file_1_g11555.',
#  'file_1_file_1_g11556.',
#  'file_1_file_1_g11557.',
#  'file_1_file_1_g11558.',
#  'file_1_file_1_g11559.',
#  'file_1_file_1_g11560.',
#  'file_1_file_1_g11561.',
#  'file_1_file_1_g11562.',
#  'file_1_file_1_g11563.',
#  'file_1_file_1_g11564.',
#  'file_1_file_1_g11565.',
#  'file_1_file_1_g11566.',
#  'file_1_file_1_g11567.',
#  'file_1_file_1_g11568.',
#  'file_1_file_1_g11569.',
#  'file_1_file_1_g11570.',
#  'file_1_file_1_g11571.',
#  'file_1_file_1_g11572.',
#  'file_1_file_1_g11573.',
#  'file_1_file_1_g11574.',
#  'file_1_file_1_g11575.',
#  'file_1_file_1_g11576.',
#  'file_1_file_1_g11577.',
#  'file_1_file_1_g11578.',
#  'file_1_file_1_g11579.',
#  'file_1_file_1_g11580.',
#  'file_1_file_1_g11581.',
#  'file_1_file_1_g11582.',
#  'file_1_file_1_g11583.',
#  'file_1_file_1_g11584.',
#  'file_1_file_1_g11585.',
#  'file_1_file_1_g11586.',
#  'file_1_file_1_g11587.',
#  'file_1_file_1_g11588.',
#  'file_1_file_1_g11589.',
#  'file_1_file_1_g11590.',
#  'file_1_file_1_g11591.',
#  'file_1_file_1_g11592.',
#  'file_1_file_1_g11593.',
#  'file_1_file_1_g11594.',
#  'file_1_file_1_g11595.',
#  'file_1_file_1_g11596.',
#  'file_1_file_1_g11597.',
#  'file_1_file_1_g11598.',
#  'file_1_file_1_g11599.',
#  'file_1_file_1_g11600.',
#  'file_1_file_1_g11601.',
#  'file_1_file_1_g11602.',
#  'file_1_file_1_g11603.',
#  'file_1_file_1_g11604.',
#  'file_1_file_1_g11605.',
#  'file_1_file_1_g11606.',
#  'file_1_file_1_g11607.',
#  'file_1_file_1_g11608.',
#  'file_1_file_1_g11609.',
#  'file_1_file_1_g11610.',
#  'file_1_file_1_g11611.',
#  'file_1_file_1_g11612.',
#  'file_1_file_1_g11613.',
#  'file_1_file_1_g11614.',
#  'file_1_file_1_g11615.',
#  'file_1_file_1_g11616.',
#  'file_1_file_1_g11617.',
#  'file_1_file_1_g11618.',
#  'file_1_file_1_g11619.',
#  'file_1_file_1_g11620.',
#  'file_1_file_1_g11621.',
#  'file_1_file_1_g11622.',
#  'file_1_file_1_g11623.',
#  'file_1_file_1_g11624.',
#  'file_1_file_1_g11625.',
#  'file_1_file_1_g11626.',
#  'file_1_file_1_g11627.',
#  'file_1_file_1_g11628.',
#  'file_1_file_1_g11629.',
#  'file_1_file_1_g11630.',
#  'file_1_file_1_g11631.',
#  'file_1_file_1_g11632.',
#  'file_1_file_1_g11633.',
#  'file_1_file_1_g11634.',
#  'file_1_file_1_g11635.',
#  'file_1_file_1_g11636.',
#  'file_1_file_1_g11637.',
#  'file_1_file_1_g11638.',
#  'file_1_file_1_g11639.',
#  'file_1_file_1_g11640.',
#  'file_1_file_1_g11641.',
#  'file_1_file_1_g11651.',
#  'file_1_file_1_g11652.',
#  'file_1_file_1_g11653.',
#  'file_1_file_1_g11654.',
#  'file_1_file_1_g11655.',
#  'file_1_file_1_g11656.',
#  'file_1_file_1_g11657.',
#  'file_1_file_1_g11658.',
#  'file_1_file_1_g11659.',
#  'file_1_file_1_g11660.',
#  'file_1_file_1_g11661.',
#  'file_1_file_1_g11662.',
#  'file_1_file_1_g11663.',
#  'file_1_file_1_g11664.',
#  'file_1_file_1_g11665.',
#  'file_1_file_1_g11666.',
#  'file_1_file_1_g11667.',
#  ...]

# %%
pri_stripped = dict(pri_pairs.transcript_id.str.rstrip('t1234567890').value_counts())

# %%
#pri_stripped

# %% [markdown]
# So now pri_stripped is a dictionary of the stripped values and how often they occour.

# %% [markdown]
# Probably best idea is to import the pri walli fasta file through biopython, then run it through a for loop with this list.

# %%
records = list(SeqIO.parse(infn_fasta, "fasta"))

# %% [markdown]
# So we can check everything in the record against pri_stripped. If its there once: keep the record as is, add to a "keep" list.
# The issue if its there >once, is that there isn't a way to search the list I dont think?

# %%
ones, twos, threes, fours, fives, sixes = 0, 0, 0, 0, 0, 0

for x in range(1,len(records)):
    if (pri_stripped[records[x].id.rstrip('t1234567890')]) < 1:
        print("got a 0???")
    elif (pri_stripped[records[x].id.rstrip('t1234567890')]) == 1:
        ones += 1
    elif (pri_stripped[records[x].id.rstrip('t1234567890')]) == 2:
        twos += 1
    elif (pri_stripped[records[x].id.rstrip('t1234567890')]) == 3:
        threes += 1
    elif (pri_stripped[records[x].id.rstrip('t1234567890')]) == 4:
        fours += 1
    elif (pri_stripped[records[x].id.rstrip('t1234567890')]) == 5:
        fives += 1
    elif (pri_stripped[records[x].id.rstrip('t1234567890')]) == 6:
        sixes += 1
    else:
        print(pri_stripped[records[x].id.rstrip('t1234567890')])
        
print("ones =", ones, "\ntwos =", twos, "\nthrees =", threes, "\nfours =", fours, "\nfives =", fives, "\nsixes =", sixes)
# Out:
# ones = 48670
# twos = 2814
# threes = 402
# fours = 44
# fives = 5
# sixes = 6

# %%
keep_records_2 = []
same_lengths = []

for key in pri_stripped:
    match_records = []
    key_lengths = []
    for x in range(0,(len(records))):
        if records[x].id.rstrip('t1234567890') == key:
            match_records += [records[x]]
            key_lengths += [len(records[x].seq)]
    if len(match_records) == 1:
        keep_records_2 += [match_records]
    elif len(match_records) < 1:
        print("oh no < 1", key)
    else:
        key_matches = zip(match_records, key_lengths)
        max_length = max(key_lengths)
        keep_records_temp = []
        for match, length in key_matches:
            if length == max_length:
                keep_records_temp += [match]
        
        if len(keep_records_temp) == 1:
            keep_records_2 += [keep_records_temp]
        else:
            same_lengths += [keep_records_temp]
print(len(keep_records_2), len(same_lengths))
# Out:
# 50201 24

# %%
len(pri_stripped)
# Out:
# 50225

# %% [markdown]
# So there is an output for each memeber of stripped - as there should be. We did not keep track of rejected records, so I can't check that all the numbers add up to len(records).
#
# Everything in same_length was 2 items long:

# %%
for x in same_lengths:
    if len(x) != 2:
        print(">2")

# %% [markdown]
# And as there were only 24, I checked them all and they were all t1 and t2 (I guess that the shorter ones get later numbers?), and decided we could just go with .t1

# %%
for x in same_lengths:
    print(len(x))
    for y in x:
        print(y.id)
# Out:
# 2
# file_1_file_1_g59336.t2
# file_1_file_1_g59336.t1
# 2
# file_1_file_1_g58502.t2
# file_1_file_1_g58502.t1
# 2
# file_1_file_1_g1788.t1
# file_1_file_1_g1788.t2
# 2
# file_1_file_1_g85029.t1
# file_1_file_1_g85029.t2
# 2
# file_1_file_1_g28230.t2
# file_1_file_1_g28230.t1
# 2
# file_1_file_1_g80471.t1
# file_1_file_1_g80471.t2
# 2
# file_1_file_1_g21480.t2
# file_1_file_1_g21480.t1
# 2
# file_1_file_1_g47304.t2
# file_1_file_1_g47304.t1
# 2
# file_1_file_1_g66009.t2
# file_1_file_1_g66009.t1
# 2
# file_1_file_1_g40930.t2
# file_1_file_1_g40930.t1
# 2
# file_1_file_1_g81899.t1
# file_1_file_1_g81899.t2
# 2
# file_1_file_1_g80086.t2
# file_1_file_1_g80086.t1
# 2
# file_1_file_1_g77976.t2
# file_1_file_1_g77976.t1
# 2
# file_1_file_1_g25233.t1
# file_1_file_1_g25233.t2
# 2
# file_1_file_1_g43213.t2
# file_1_file_1_g43213.t1
# 2
# file_1_file_1_g64815.t1
# file_1_file_1_g64815.t2
# 2
# file_1_file_1_g49201.t1
# file_1_file_1_g49201.t2
# 2
# file_1_file_1_g25956.t1
# file_1_file_1_g25956.t2
# 2
# file_1_file_1_g21353.t2
# file_1_file_1_g21353.t1
# 2
# file_1_file_1_g84309.t2
# file_1_file_1_g84309.t1
# 2
# file_1_file_1_g48220.t1
# file_1_file_1_g48220.t2
# 2
# file_1_file_1_g52743.t2
# file_1_file_1_g52743.t1
# 2
# file_1_file_1_g4069.t1
# file_1_file_1_g4069.t2
# 2
# file_1_file_1_g23351.t2
# file_1_file_1_g23351.t1

# %% [markdown]
# This one takes FOREVER so is hashed out

# %%
keep_records_2 = []

#for each key
for key in pri_stripped:
    match_records = []
    key_lengths = []
    
#find all the records which match the given key
    for x in range(0,(len(records))):
        if records[x].id.rstrip('t1234567890') == key:
            match_records += [records[x]]
            key_lengths += [len(records[x].seq)]
            
#move on if there is only one match (and error if <1)
    if len(match_records) == 1:
        keep_records_2 += match_records
    elif len(match_records) < 1:
        print("oh no < 1", key)

#if there are multiple maches, find all which are the longest length
    else:
        key_matches = zip(match_records, key_lengths)
        max_length = max(key_lengths)
        keep_records_temp = []
        for match, length in key_matches:
            if length == max_length:
                keep_records_temp += [match]
                
#move on if thats only one thing
        if len(keep_records_temp) == 1:
            keep_records_2 += keep_records_temp

#or take the .t1 if its more than one.
        else:
            t1 = keep_records_temp[0].id.rstrip('t1234567890') + "t1"
            for y in keep_records_temp:
                if y.id == t1:
                    keep_records_2 += [y]
print(len(keep_records_2))
# Out:
# 50225

# %%
keep_records_ids = []
for record in keep_records_2:
    keep_records_ids += [record.id]
print(keep_records_ids[:10])
# Out:
# ['file_1_file_1_g5851.t6', 'file_1_file_1_g83002.t4', 'file_1_file_1_g7707.t3', 'file_1_file_1_g20541.t3', 'file_1_file_1_g19219.t4', 'file_1_file_1_g33615.t3', 'file_1_file_1_g26460.t2', 'file_1_file_1_g70243.t2', 'file_1_file_1_g69049.t3', 'file_1_file_1_g26794.t1']

# %% [markdown]
# so then I think keep_records_2 is the records. And keep_records_ids is just the ids. I dont really like using biopython to export a fasta file, so I'm gonna use bash again.

# %%
joined_ids = "\n".join(keep_records_ids) + "\n"

# %%
with open((outpath + "longest_cds_pri.txt"), "w") as f:
    f.write(joined_ids)

# %%
# %%bash -s "$outpath"
# cd $1
# seqtk subseq W_ceracea_both.fa longest_cds_pri.txt > W_ceracea_longest.fa
# grep -c ">" W_ceracea_longest.fa
# Out:
# 50225

# %%
len(pri_stripped)
# Out:
# 50225

# %% [markdown]
# So assuming pri_stripped is right, W_ceracea_longest.fa is right.
